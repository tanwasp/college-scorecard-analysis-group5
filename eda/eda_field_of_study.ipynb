# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Avoid SettingWithCopyWarning
pd.options.mode.copy_on_write = True

# %%
# Loading up the dataset and setting the datatype of "OPEID" and "OPEID6" column to string
field_of_study_data = pd.read_csv('../data/Most-Recent-Cohorts-Field-of-Study.csv', dtype={"OPEID6": str}, low_memory=False)

# %%
# Make a copy of the original dataset
field_of_study_data_orig = field_of_study_data.copy()

# %%
field_of_study_data
# Out:
#           UNITID  OPEID6                        INSTNM CONTROL  MAIN  CIPCODE  \
# 0       100654.0  001002      Alabama A & M University  Public     1      100
# 1       100654.0  001002      Alabama A & M University  Public     1      101
# 2       100654.0  001002      Alabama A & M University  Public     1      109
# 3       100654.0  001002      Alabama A & M University  Public     1      110
# 4       100654.0  001002      Alabama A & M University  Public     1      110
# ...          ...     ...                           ...     ...   ...      ...
# 229183       NaN  043006  Southeast New Mexico College  Public     1     5201
# 229184       NaN  043006  Southeast New Mexico College  Public     1     5203
# 229185       NaN  043006  Southeast New Mexico College  Public     1     5204
# 229186       NaN  043006  Southeast New Mexico College  Public     1     5204
# 229187       NaN  043006  Southeast New Mexico College  Public     1     5214
#
# ...

# %%
# Check the dimensions of the DataFrame
field_of_study_data.shape
# Out:
# (229188, 174)

# %%
unused_variables = ["DEBT_ALL", "DEBT_MALE", "DEBT_NOTMALE", "_HI_", "EARN_COUNT_MALE", "EARN_COUNT_NOMALE", "_DLNQ", "_FBR", "_DFR", "_NOPROG", "_MAKEPROG", "_DISCHARGE"]

for variables in unused_variables:
    field_of_study_data = field_of_study_data.loc[:, ~field_of_study_data.columns.str.contains(variables, case=False)]

# %%
field_of_study_data.to_csv("field_of_study_data.csv")
